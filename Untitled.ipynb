# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Read the datasets

df1 = pd.read_csv("data/tngross.csv")
df2 = pd.read_csv("data/tnproduction.csv")

# %%
df = df1.merge(df2, on="Unnamed: 0")

df = df.drop("Unnamed: 0", axis=1)

df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce', format='%b %d, %Y')

# Create a function to change the format of the dollar amount values

def dollar_to_int(column):
    return column.str.replace('$', '').str.replace(',', '').map(int)

df[['production_budget', 'domestic_gross', 'worldwide_gross']] = df[['production_budget', 'domestic_gross', 'worldwide_gross']].apply(dollar_to_int)

df = df[~(df['worldwide_gross']==0)]

df['earnings'] = df["worldwide_gross"] - df["production_budget"]
df['earnings_ratio'] = df["worldwide_gross"] / df["production_budget"]

df = df[~df['release_date'].isna()]

df['year'] = pd.DatetimeIndex(df['release_date']).year

df['category'] = 'Profitable'
df.loc[df['earnings_ratio'] < 1, 'category'] = 'Non-Profitable'

# %%
century_df = df[df['year']>=2000]

# %%
century_df['genres'].value_counts()
# Out:
# Drama                  1192
# Comedy                  732
# Adventure               546
# Action                  521
# Thriller/Suspense       476
# Horror                  327
# Romantic Comedy         200
# Documentary             104
# Black Comedy             70
# Musical                  56
# None                     53
# Western                  38
# Concert/Performance      13
# Multiple Genres           2
# Name: genres, dtype: int64

# %%
century_df = century_df[(century_df['genre']=='Drama') |
                        (century_df['genre']=='Comedy') |
                        (century_df['genre']=='Adventure') |
                        (century_df['genre']=='Action') |
                        (century_df['genre']=='Thriller/Suspense') |
                        (century_df['genre']=='Horror')]

# %%
decade_df = df[df['year']>=2010]

# %%
horror_df = df[df['genres']=='Horror']

# %%
others_df = df.copy()

# %%
others_df.loc[others_df['genres']!='Horror', 'genres'] = 'Other'

# %%
horror_df.sort_values('earnings', ascending=False)
# Out:
#      release_date                    movie  production_budget  domestic_gross  \
# 1723   2017-08-31                       It           35000000       328828874
# 3543   1975-06-20                     Jaws           12000000       260000000
# 181    2007-12-14              I am Legend          150000000       256393010
# 3544   1973-12-26             The Exorcist           12000000       230347346
# 744    2019-09-04          It: Chapter Two           70000000       211593228
# ...           ...                      ...                ...             ...
# 1602   2002-08-30               FearDotCom           40000000        13208023
# 1128   1998-10-16                  Beloved           53000000        22852487
# 991    1997-08-15            Event Horizon           60000000        26673242
# 662    2004-08-20  Exorcist: The Beginning           78000000        41814863
# 1111   2002-09-20              Eye See You           55000000           79161
#
#       worldwide_gross runtime_minutes  genres  \
# 1723        701083042     135 minutes  Horror
# 3543        470700000     124 minutes  Horror
# 181         585532684     100 minutes  Horror
# 3544        428214478     121 minutes  Horror
# 744         469566806     169 minutes  Horror
# ...               ...             ...     ...
# 1602         13289290     101 minutes  Horror
# 1128         22852487     171 minutes  Horror
# 991          26673953      95 minutes  Horror
# 662          43957541     114 minutes  Horror
# 1111          1807990      96 minutes  Horror
#
#                                      production_company  \
# 1723  Lin Pictures, Vertigo Entertainment, KatzSmith...
# 3543    Universal Pictures, Zancuk Company, David Brown
# 181   Village Roadshow Productions, Weed Road Pictur...
# 3544                                       Warner Bros.
# 744   New Line Cinema, Vertigo Entertainment, Rideba...
# ...                                                 ...
# 1602                                               None
# 1128                                               None
# 991          Paramount Pictures, Lawrence Gordon, Golar
# 662                            Morgan Creek Productions
# 1111                           Millennium Entertainment
#
#           production_country   earnings  earnings_ratio  year        category
# 1723           United States  666083042       20.030944  2017      Profitable
# 3543           United States  458700000       39.225000  1975      Profitable
# 181            United States  435532684        3.903551  2007      Profitable
# 3544           United States  416214478       35.684540  1973      Profitable
# 744            United States  399566806        6.708097  2019      Profitable
# ...                      ...        ...             ...   ...             ...
# 1602                    None  -26710710        0.332232  2002  Non-Profitable
# 1128           United States  -30147513        0.431179  1998  Non-Profitable
# 991            United States  -33326047        0.444566  1997  Non-Profitable
# 662           Italy, Morocco  -34042459        0.563558  2004  Non-Profitable
# 1111  Germany, United States  -53192010        0.032873  2002  Non-Profitable
#
# [449 rows x 13 columns]

# %%
horror_df['category'].value_counts()
# Out:
# Profitable        353
# Non-Profitable     96
# Name: category, dtype: int64

# %%
horror_years_df = horror_df.groupby('year', as_index=False).count()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

sns.lineplot(
    x="year", 
    y="movie",
    data = horror_years_df,)
plt.title("Horror Movies per Year")
plt.xlabel("Year")
plt.ylabel("Horror Movie Count")

plt.show()

# %%
horror_df.groupby('year', as_index=False)['movie'].count()
# Out:
#     year  movie
# 0   1933      1
# 1   1953      1
# 2   1968      2
# 3   1973      1
# 4   1974      1
# 5   1975      1
# 6   1976      2
# 7   1977      1
# 8   1978      2
# 9   1979      3
# 10  1980      3
# 11  1981      4
# 12  1982      5
# 13  1983      3
# 14  1984      4
# 15  1985      6
# 16  1986      5
# 17  1987      7
# 18  1988      9
# 19  1989      5
# 20  1990      4
# 21  1991      4
# 22  1992      3
# 23  1993      5
# 24  1994      4
# 25  1995      4
# 26  1996      4
# 27  1997      7
# 28  1998      8
# 29  1999     13
# 30  2000      9
# 31  2001      8
# 32  2002     10
# 33  2003     13
# 34  2004     11
# 35  2005     22
# 36  2006     20
# 37  2007     19
# 38  2008     16
# 39  2009     14
# 40  2010     19
# 41  2011     19
# 42  2012     18
# 43  2013     12
# 44  2014     14
# 45  2015     16
# 46  2016     20
# 47  2017     14
# 48  2018     16
# 49  2019     17
# 50  2020     11
# 51  2021      9

# %%
horror_gross_df = horror_df.groupby('year', as_index=False).median()

# %%
horror_gross_df
# Out:
#     year  production_budget  domestic_gross  worldwide_gross     earnings  \
# 0   1933           672000.0      10000000.0       10001782.0    9329782.0
# 1   1953           658000.0      23800000.0       23800000.0   23142000.0
# 2   1968          1657000.0      22741245.0       31741902.0   30084902.0
# 3   1973         12000000.0     230347346.0      428214478.0  416214478.0
# 4   1974           140000.0      26572439.0       26572439.0   26432439.0
# 5   1975         12000000.0     260000000.0      470700000.0  458700000.0
# 6   1976          2300000.0      37224519.0       37231980.5   34931980.5
# 7   1977         14000000.0      25011000.0       25011000.0   11011000.0
# 8   1978         10162500.0      75098188.0      139587188.0  129424688.0
# 9   1979         10700000.0      22673340.0       55000000.0   53500000.0
# 10  1980          1100000.0      39754601.0       45605374.0   26605374.0
# 11  1981          1125000.0      22808388.0       22808388.0   21753297.0
# 12  1982          2500000.0      20036244.0       20036244.0   12036244.0
# 13  1983          5952000.0       2400000.0       29400000.0   19500000.0
# 14  1984          2200000.0      20320691.5       20339888.0   13596453.0
# 15  1985          3750000.0      12920712.5       17700939.5   14200939.5
# 16  1986          4700000.0       8025872.0        8025872.0    5369373.0
# 17  1987          3500000.0      14564000.0       14575148.0   10500000.0
# 18  1988          5000000.0      14114000.0       14114000.0    4614000.0
# 19  1989          6000000.0      14343976.0       14343976.0    9343976.0
# 20  1990         19500000.0      40056376.0       43687376.0   21687376.0
# 21  1991          8000000.0      21848293.0       21848293.0   15848293.0
# 22  1992         11000000.0      21171695.0       21171695.0   10171695.0
# 23  1993          3000000.0       9579068.0        9579068.0     902679.0
# 24  1994         47500000.0      43509026.5      121509026.5   64009026.5
# 25  1995          9000000.0      17382047.5       17382047.5    7436857.5
# 26  1996         15000000.0      25249213.5       40702814.0   23202814.0
# 27  1997         45000000.0      61007424.0      125250091.0   91998907.0
# 28  1998         20000000.0      35260447.5       40151971.5   21254769.5
# 29  1999         21000000.0      31770413.0       31770413.0   11059379.0
# 30  2000         23000000.0      33000377.0       47721314.0   30182088.0
# 31  2001         12000000.0      29144155.5       39661585.5   29661585.5
# 32  2002         35000000.0      30186571.5       33983728.0    8695176.5
# 33  2003         10000000.0      33685268.0       75685268.0   40289758.0
# 34  2004         25000000.0      31526393.0       43957541.0   23809206.0
# 35  2005         19487500.0      26842715.0       48612054.0   23476795.0
# 36  2006         15625000.0      30499699.5       44341273.5   26341273.5
# 37  2007         15000000.0      25126214.0       57189408.0   37774833.0
# 38  2008         10400000.0      15437628.0       19114410.0    9032969.5
# 39  2009         14500000.0      33072594.0       58139322.5   45139322.5
# 40  2010         19000000.0      30101577.0       56445534.0   31445503.0
# 41  2011         20000000.0      18298649.0       27573078.0     151887.0
# 42  2012          5950000.0      17824929.5       43257851.5   36589827.0
# 43  2013          4500000.0      34804282.0       65037766.5   40037766.5
# 44  2014          5000000.0       8821722.0       21814237.0   17314237.0
# 45  2015          7500000.0      26771262.5       57946309.0   42830349.5
# 46  2016          6375000.0      12788417.5       25945342.0   18445342.0
# 47  2017          8200000.0      41180012.5       93570299.0   76070299.0
# 48  2018         10000000.0      27828320.5       48953102.0   42203102.0
# 49  2019         10000000.0      31581712.0       61220784.0   39503265.0
# 50  2020          7000000.0      12611536.0       18976477.0    8976477.0
# 51  2021         20000000.0      32638038.0       51788711.0   36788711.0
#
#     earnings_ratio
# 0        14.883604
# 1        36.170213
# 2       137.179048
# 3        35.684540
# 4       189.803136
# 5        39.225000
# 6        15.865244
# 7         1.786500
# 8       113.336356
# 9        17.261214
# 10       19.496200
# 11       17.681610
# 12        5.760000
# 13        2.950000
# 14        8.222477
# 15        5.307068
# 16        2.589553
# 17        3.811337
# 18        2.427617
# 19        2.868795
# 20        2.037199
# 21        4.117529
# 22        2.033096
# 23        1.300893
# 24        2.375151
# 25        1.860762
# 26        2.499053
# 27        2.684341
# 28        1.944499
# 29        1.921615
# 30        2.312265
# 31        2.820995
# 32        1.277309
# 33        3.537120
# 34        2.503375
# 35        2.411473
# 36        2.755432
# 37        3.360927
# 38        2.215988
# 39        3.296514
# 40        2.572275
# 41        1.075943
# 42        3.250527
# 43        7.138819
# 44        3.336540
# 45        6.541142
# 46        3.239790
# 47        7.318445
# 48        7.635985
# 49        5.203425
# 50        1.897648
# 51        3.452581

# %%
fig, ax = plt.subplots(figsize=(12, 7))

sns.lineplot(
    x="year", 
    y="worldwide_gross",
    data = horror_gross_df,)
plt.title("Median Worldwide Gross per Year")
plt.xlabel("Year")
plt.ylabel("Worldwide Gross")

plt.show()

# %%
# fig, ax = plt.subplots()

# sns.lineplot(
#     x="year", 
#     color="#F34F1C",
#     data = horror_df,)
# plt.title("Non-Profitable Horror Movies per Month")
# plt.xlabel("Month")
# plt.ylabel("Horror Movie Count")

# plt.xticks(range(12), ['Jan','Feb','Mar','Apr','May','Jun','July','Aug','Sep','Oct','Nov','Dec'])

# plt.show()
