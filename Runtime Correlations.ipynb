# %% [markdown]
# # Runtime Correlations

# %%
import pandas as pd

# %%
#import relevant tables
box_office_mojo = pd.read_csv("./data/bom.movie_gross.csv")

imdb_name = pd.read_csv("./data/name.basics.csv")
imdb_title = pd.read_csv("./data/title.basics.csv")
imdb_crew = pd.read_csv("./data/title.crew.csv") 
imdb_principals = pd.read_csv("./data/title.principals.csv")
imdb_ratings = pd.read_csv("./data/title.ratings.csv")
imdb_akas = pd.read_csv("./data/title.akas.csv")

rt_info = pd.read_csv("./data/rt.movie_info.tsv", sep = "\t")
rt_reviews = pd.read_csv("./data/rt.reviews.tsv", sep = "\t", encoding='windows-1252')

the_movie_db = pd.read_csv("./data/tmdb.movies.csv")

movie_budgets = pd.read_csv("./data/tngross.csv")
movie_production = pd.read_csv("./data/tnproduction.csv")

# %%
movie_production
# Out:
#       Unnamed: 0 runtime_minutes       genres    production_company  \
# 0              0     181 minutes       Action        Marvel Studios
# 1              1     136 minutes    Adventure  Walt Disney Pictures
# 2              2     141 minutes       Action        Marvel Studios
# 3              3     136 minutes    Adventure  Lucasfilm, Bad Robot
# 4              4     156 minutes       Action        Marvel Studios
# ...          ...             ...          ...                   ...
# 6095        6095      90 minutes        Drama                  None
# 6096        6096      88 minutes    Adventure         Phebean Films
# 6097        6097            None  Documentary                  None
# 6098        6098            None       Horror                  None
# 6099        6099      81 minutes        Drama                  None
#
#      production_country
# 0         United States
# 1         United States
# 2         United States
# 3         United States
# 4         United States
# ...                 ...
# 6095      United States
# 6096            Nigeria
# 6097      United States
# 6098      United States
# 6099      United States
#
# [6100 rows x 5 columns]

# %%
movie_budgets
# Out:
#       Unnamed: 0  release_date                                        movie  \
# 0              0  Apr 23, 2019                            Avengers: Endgame
# 1              1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              2  Apr 22, 2015                      Avengers: Age of Ultron
# 3              3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              4  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6095        6095  Mar 17, 2015                                      Closure
# 6096        6096  Aug 29, 2015                            Lunch Time Heroes
# 6097        6097  Mar 25, 2015                                  Open Secret
# 6098        6098  Nov 10, 2015                            The Night Visitor
# 6099        6099   Jul 7, 2015                                 Tiger Orange
#
#      production_budget domestic_gross worldwide_gross
# 0         $400,000,000   $858,373,000  $2,797,800,564
# 1         $379,000,000   $241,071,802  $1,045,713,802
# 2         $365,000,000   $459,005,868  $1,395,316,979
# 3         $306,000,000   $936,662,225  $2,064,615,817
# 4         $300,000,000   $678,815,482  $2,044,540,523
# ...                ...            ...             ...
# 6095          $100,000             $0              $0
# 6096          $100,000             $0              $0
# 6097          $100,000             $0              $0
# 6098          $100,000             $0              $0
# 6099          $100,000             $0              $0
#
# [6100 rows x 6 columns]

# %%
df = movie_production.merge(movie_budgets, on ="Unnamed: 0")

# %%
df
# Out:
#       Unnamed: 0 runtime_minutes       genres    production_company  \
# 0              0     181 minutes       Action        Marvel Studios
# 1              1     136 minutes    Adventure  Walt Disney Pictures
# 2              2     141 minutes       Action        Marvel Studios
# 3              3     136 minutes    Adventure  Lucasfilm, Bad Robot
# 4              4     156 minutes       Action        Marvel Studios
# ...          ...             ...          ...                   ...
# 6095        6095      90 minutes        Drama                  None
# 6096        6096      88 minutes    Adventure         Phebean Films
# 6097        6097            None  Documentary                  None
# 6098        6098            None       Horror                  None
# 6099        6099      81 minutes        Drama                  None
#
#      production_country  release_date  \
# 0         United States  Apr 23, 2019
# 1         United States  May 20, 2011
# 2         United States  Apr 22, 2015
# 3         United States  Dec 16, 2015
# 4         United States  Apr 25, 2018
# ...                 ...           ...
# 6095      United States  Mar 17, 2015
# 6096            Nigeria  Aug 29, 2015
# 6097      United States  Mar 25, 2015
# 6098      United States  Nov 10, 2015
# 6099      United States   Jul 7, 2015
#
#                                             movie production_budget  \
# 0                               Avengers: Endgame      $400,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $379,000,000
# 2                         Avengers: Age of Ultron      $365,000,000
# 3            Star Wars Ep. VII: The Force Awakens      $306,000,000
# 4                          Avengers: Infinity War      $300,000,000
# ...                                           ...               ...
# 6095                                      Closure          $100,000
# 6096                            Lunch Time Heroes          $100,000
# 6097                                  Open Secret          $100,000
# 6098                            The Night Visitor          $100,000
# 6099                                 Tiger Orange          $100,000
#
#      domestic_gross worldwide_gross
# 0      $858,373,000  $2,797,800,564
# 1      $241,071,802  $1,045,713,802
# 2      $459,005,868  $1,395,316,979
# 3      $936,662,225  $2,064,615,817
# 4      $678,815,482  $2,044,540,523
# ...             ...             ...
# 6095             $0              $0
# 6096             $0              $0
# 6097             $0              $0
# 6098             $0              $0
# 6099             $0              $0
#
# [6100 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6100 entries, 0 to 6099
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          6100 non-null   int64
#  1   runtime_minutes     6100 non-null   object
#  2   genres              6100 non-null   object
#  3   production_company  6100 non-null   object
#  4   production_country  6100 non-null   object
#  5   release_date        6100 non-null   object
#  6   movie               6100 non-null   object
#  7   production_budget   6100 non-null   int64
#  8   domestic_gross      6100 non-null   object
#  9   worldwide_gross     6100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 524.2+ KB

# %%
df['production_budget'] = df['production_budget'].str.replace('$', '')
df['production_budget'] = df['production_budget'].str.replace(',', '').astype(int)
df['worldwide_gross'] = df['worldwide_gross'].str.replace('$', '')
df['worldwide_gross'] = df['worldwide_gross'].str.replace(',', '').astype(int)

# %%
df
# Out:
#       Unnamed: 0 runtime_minutes       genres    production_company  \
# 0              0            181        Action        Marvel Studios
# 1              1            136     Adventure  Walt Disney Pictures
# 2              2            141        Action        Marvel Studios
# 3              3            136     Adventure  Lucasfilm, Bad Robot
# 4              4            156        Action        Marvel Studios
# ...          ...             ...          ...                   ...
# 6095        6095             90         Drama                  None
# 6096        6096             88     Adventure         Phebean Films
# 6097        6097            None  Documentary                  None
# 6098        6098            None       Horror                  None
# 6099        6099             81         Drama                  None
#
#      production_country  release_date  \
# 0         United States  Apr 23, 2019
# 1         United States  May 20, 2011
# 2         United States  Apr 22, 2015
# 3         United States  Dec 16, 2015
# 4         United States  Apr 25, 2018
# ...                 ...           ...
# 6095      United States  Mar 17, 2015
# 6096            Nigeria  Aug 29, 2015
# 6097      United States  Mar 25, 2015
# 6098      United States  Nov 10, 2015
# 6099      United States   Jul 7, 2015
#
#                                             movie  production_budget  \
# 0                               Avengers: Endgame          400000000
# 1     Pirates of the Caribbean: On Stranger Tides          379000000
# 2                         Avengers: Age of Ultron          365000000
# 3            Star Wars Ep. VII: The Force Awakens          306000000
# 4                          Avengers: Infinity War          300000000
# ...                                           ...                ...
# 6095                                      Closure             100000
# 6096                            Lunch Time Heroes             100000
# 6097                                  Open Secret             100000
# 6098                            The Night Visitor             100000
# 6099                                 Tiger Orange             100000
#
#      domestic_gross  worldwide_gross
# 0      $858,373,000       2797800564
# 1      $241,071,802       1045713802
# 2      $459,005,868       1395316979
# 3      $936,662,225       2064615817
# 4      $678,815,482       2044540523
# ...             ...              ...
# 6095             $0                0
# 6096             $0                0
# 6097             $0                0
# 6098             $0                0
# 6099             $0                0
#
# [6100 rows x 10 columns]

# %%
df['runtime_minutes'] = df['runtime_minutes'].str.replace('minutes', '')

# %%
df['profit'] =  df['worldwide_gross'] / df['production_budget']

# %%
df
# Out:
#       Unnamed: 0 runtime_minutes       genres    production_company  \
# 0              0            181        Action        Marvel Studios
# 1              1            136     Adventure  Walt Disney Pictures
# 2              2            141        Action        Marvel Studios
# 3              3            136     Adventure  Lucasfilm, Bad Robot
# 4              4            156        Action        Marvel Studios
# ...          ...             ...          ...                   ...
# 6095        6095             90         Drama                  None
# 6096        6096             88     Adventure         Phebean Films
# 6097        6097            None  Documentary                  None
# 6098        6098            None       Horror                  None
# 6099        6099             81         Drama                  None
#
#      production_country  release_date  \
# 0         United States  Apr 23, 2019
# 1         United States  May 20, 2011
# 2         United States  Apr 22, 2015
# 3         United States  Dec 16, 2015
# 4         United States  Apr 25, 2018
# ...                 ...           ...
# 6095      United States  Mar 17, 2015
# 6096            Nigeria  Aug 29, 2015
# 6097      United States  Mar 25, 2015
# 6098      United States  Nov 10, 2015
# 6099      United States   Jul 7, 2015
#
#                                             movie  production_budget  \
# 0                               Avengers: Endgame          400000000
# 1     Pirates of the Caribbean: On Stranger Tides          379000000
# 2                         Avengers: Age of Ultron          365000000
# 3            Star Wars Ep. VII: The Force Awakens          306000000
# 4                          Avengers: Infinity War          300000000
# ...                                           ...                ...
# 6095                                      Closure             100000
# 6096                            Lunch Time Heroes             100000
# 6097                                  Open Secret             100000
# 6098                            The Night Visitor             100000
# 6099                                 Tiger Orange             100000
#
#      domestic_gross  worldwide_gross    profit
# 0      $858,373,000       2797800564  6.994501
# 1      $241,071,802       1045713802  2.759139
# 2      $459,005,868       1395316979  3.822786
# 3      $936,662,225       2064615817  6.747111
# 4      $678,815,482       2044540523  6.815135
# ...             ...              ...       ...
# 6095             $0                0  0.000000
# 6096             $0                0  0.000000
# 6097             $0                0  0.000000
# 6098             $0                0  0.000000
# 6099             $0                0  0.000000
#
# [6100 rows x 11 columns]

# %%
df = df.sort_values(by=['profit'], ascending=False)

# %%
df.head(20)
# Out:
#       Unnamed: 0 runtime_minutes             genres  \
# 6013        6013             93              Action
# 5882        5882             96              Horror
# 6080        6080             81              Horror
# 5794        5794             81              Horror
# 5728        5728             70           Adventure
# 6077        6077             96              Horror
# 5583        5583            119               Drama
# 5930        5930             91              Horror
# 6066        6066             83              Horror
# 5754        5754            112               Drama
# 6058        6058             82               Drama
# 6012        6012             93                None
# 5486        5486             83             Musical
# 5739        5739            112             Western
# 5899        5899             96              Comedy
# 5818        5818             79   Thriller/Suspense
# 5812        5812             96              Horror
# 6081        6081            None              Drama
# 5584        5584             83              Horror
# 6057        6057            None               None
#
#                                      production_company  \
# 6013                                     Roadshow Films
# 5882                            Blumhouse, Solana Films
# 6080  New Line Cinema, Blumhouse, Tremendum Pictures...
# 5794                                               None
# 5728                      Walt Disney Animation Studios
# 6077                                               None
# 5583                                               None
# 5930                                               None
# 6066                                               None
# 5754                    Lucas Film LTD, Coppola Company
# 6058                                               None
# 6012                                               None
# 5486                               Walt Disney Pictures
# 5739                                               None
# 5899  Fox Searchlight Pictures, Paramount Pictures, ...
# 5818                                               None
# 5812     Paramount Pictures, Georgetown Productions Inc
# 6081                                               None
# 5584                        Insurge Pictures, Prototype
# 6057                                               None
#
#                  production_country  release_date  \
# 6013                      Australia  Apr 12, 1979
# 5882                  United States  Sep 25, 2009
# 6080                  United States   Jul 9, 2015
# 5794                  United States  Jul 14, 1999
# 5728                  United States  Aug 13, 1942
# 6077                  United States   Oct 1, 1968
# 5583                  United States  Nov 21, 1976
# 5930                  United States  Oct 17, 1978
# 6066                  United States  Oct 18, 1974
# 5754                  United States  Aug 11, 1973
# 6058                        Ireland  May 16, 2007
# 6012                  United States  Jul 25, 1969
# 5486                  United States  Dec 21, 1937
# 5739                  United States   Jan 1, 1971
# 5899                  United States  Jun 11, 2004
# 5818                  United States   Aug 6, 2004
# 5812                  United States   May 9, 1980
# 6081                  United States  Sep 29, 2006
# 5584  Italy, Romania, United States   Jan 6, 2012
# 6057                  United States   Jan 1, 1971
#
#                                    movie  production_budget domestic_gross  \
# 6013                             Mad Max             200000     $8,750,000
# 5882                 Paranormal Activity             450000   $107,918,810
# 6080                         The Gallows             100000    $22,764,410
# 5794             The Blair Witch Project             600000   $140,539,099
# 5728                               Bambi             858000   $102,797,000
# 6077            Night of the Living Dead             114000    $12,087,064
# 5583                               Rocky            1000000   $117,235,147
# 5930                           Halloween             325000    $47,274,000
# 6066         The Texas Chainsaw Massacre             140000    $26,572,439
# 5754                   American Graffiti             777000   $115,000,000
# 6058                                Once             150000     $9,445,857
# 6012                    The Stewardesses             200000    $13,500,000
# 5486     Snow White and the Seven Dwarfs            1488000   $184,925,486
# 5739                          Billy Jack             800000    $98,000,000
# 5899                   Napoleon Dynamite             400000    $44,540,956
# 5818                          Open Water             500000    $30,500,882
# 5812                     Friday the 13th             550000    $39,754,601
# 6081                   Facing the Giants             100000    $10,178,331
# 5584                    The Devil Inside            1000000    $53,262,945
# 6057  Sweet Sweetback's Baad Asssss Song             150000    $15,200,000
#
#       worldwide_gross      profit
# 6013         99750000  498.750000
# 5882        194183034  431.517853
# 6080         41656474  416.564740
# 5794        248300000  413.833333
# 5728        268000000  312.354312
# 6077         30087064  263.921614
# 5583        225000000  225.000000
# 5930         70274000  216.227692
# 6066         26572439  189.803136
# 5754        140000000  180.180180
# 6058         23151277  154.341847
# 6012         25000000  125.000000
# 5486        184925486  124.277880
# 5739         98000000  122.500000
# 5899         46122713  115.306782
# 5818         55518641  111.037282
# 5812         59754601  108.644729
# 6081         10243159  102.431590
# 5584        101759490  101.759490
# 6057         15200000  101.333333

# %%
df.describe()
# Out:
#         Unnamed: 0  production_budget  worldwide_gross       profit
# count  6100.000000       6.100000e+03     6.100000e+03  6100.000000
# mean   3049.500000       3.198528e+07     9.271192e+07     4.146160
# std    1761.062653       4.203144e+07     1.803505e+08    15.721206
# min       0.000000       1.000000e+05     0.000000e+00     0.000000
# 25%    1524.750000       5.000000e+06     4.502229e+06     0.498764
# 50%    3049.500000       1.700000e+07     2.833264e+07     1.697085
# 75%    4574.250000       4.000000e+07     9.748378e+07     3.730636
# max    6099.000000       4.000000e+08     2.845900e+09   498.750000

# %%
fifty_percentile = df[df['profit'] >= 1.7]

# %%
fifty_percentile
# Out:
#       Unnamed: 0 runtime_minutes             genres  \
# 6013        6013             93              Action
# 5882        5882             96              Horror
# 6080        6080             81              Horror
# 5794        5794             81              Horror
# 5728        5728             70           Adventure
# ...          ...             ...                ...
# 403          403             97              Comedy
# 933          933            114   Thriller/Suspense
# 1345        1345            137               Drama
# 3834        3834             81              Comedy
# 621          621            130           Adventure
#
#                                      production_company production_country  \
# 6013                                     Roadshow Films          Australia
# 5882                            Blumhouse, Solana Films      United States
# 6080  New Line Cinema, Blumhouse, Tremendum Pictures...      United States
# 5794                                               None      United States
# 5728                      Walt Disney Animation Studios      United States
# ...                                                 ...                ...
# 403   Gary Sanchez Productions, Mosaic Media, Sony P...      United States
# 933                                                None      United States
# 1345                          MTV Films, Tollin/Robbins      United States
# 3834                                               None      United States
# 621   New Line Cinema, Prelude Pictures, Irwin Allen...      United States
#
#       release_date                     movie  production_budget  \
# 6013  Apr 12, 1979                   Mad Max             200000
# 5882  Sep 25, 2009       Paranormal Activity             450000
# 6080   Jul 9, 2015               The Gallows             100000
# 5794  Jul 14, 1999   The Blair Witch Project             600000
# 5728  Aug 13, 1942                     Bambi             858000
# ...            ...                       ...                ...
# 403    Aug 6, 2010            The Other Guys          100000000
# 933    Oct 1, 2004                 Ladder 49           60000000
# 1345  Jan 14, 2005              Coach Carter           45000000
# 3834  Jan 25, 2002  Kung Pow: Enter the Fist           10000000
# 621    Apr 3, 1998             Lost In Space           80000000
#
#      domestic_gross  worldwide_gross      profit
# 6013     $8,750,000         99750000  498.750000
# 5882   $107,918,810        194183034  431.517853
# 6080    $22,764,410         41656474  416.564740
# 5794   $140,539,099        248300000  413.833333
# 5728   $102,797,000        268000000  312.354312
# ...             ...              ...         ...
# 403    $119,219,978        170936470    1.709365
# 933     $74,541,707        102332848    1.705547
# 1345    $67,264,877         76665507    1.703678
# 3834    $16,033,556         17033556    1.703356
# 621     $69,117,629        136047317    1.700591
#
# [2774 rows x 11 columns]

# %%
fifty_percentile = fifty_percentile[fifty_percentile['runtime_minutes'] != 'None']

# %%
fifty_percentile
# Out:
#       Unnamed: 0 runtime_minutes             genres  \
# 6013        6013             93              Action
# 5882        5882             96              Horror
# 6080        6080             81              Horror
# 5794        5794             81              Horror
# 5728        5728             70           Adventure
# ...          ...             ...                ...
# 403          403             97              Comedy
# 933          933            114   Thriller/Suspense
# 1345        1345            137               Drama
# 3834        3834             81              Comedy
# 621          621            130           Adventure
#
#                                      production_company production_country  \
# 6013                                     Roadshow Films          Australia
# 5882                            Blumhouse, Solana Films      United States
# 6080  New Line Cinema, Blumhouse, Tremendum Pictures...      United States
# 5794                                               None      United States
# 5728                      Walt Disney Animation Studios      United States
# ...                                                 ...                ...
# 403   Gary Sanchez Productions, Mosaic Media, Sony P...      United States
# 933                                                None      United States
# 1345                          MTV Films, Tollin/Robbins      United States
# 3834                                               None      United States
# 621   New Line Cinema, Prelude Pictures, Irwin Allen...      United States
#
#       release_date                     movie  production_budget  \
# 6013  Apr 12, 1979                   Mad Max             200000
# 5882  Sep 25, 2009       Paranormal Activity             450000
# 6080   Jul 9, 2015               The Gallows             100000
# 5794  Jul 14, 1999   The Blair Witch Project             600000
# 5728  Aug 13, 1942                     Bambi             858000
# ...            ...                       ...                ...
# 403    Aug 6, 2010            The Other Guys          100000000
# 933    Oct 1, 2004                 Ladder 49           60000000
# 1345  Jan 14, 2005              Coach Carter           45000000
# 3834  Jan 25, 2002  Kung Pow: Enter the Fist           10000000
# 621    Apr 3, 1998             Lost In Space           80000000
#
#      domestic_gross  worldwide_gross      profit
# 6013     $8,750,000         99750000  498.750000
# 5882   $107,918,810        194183034  431.517853
# 6080    $22,764,410         41656474  416.564740
# 5794   $140,539,099        248300000  413.833333
# 5728   $102,797,000        268000000  312.354312
# ...             ...              ...         ...
# 403    $119,219,978        170936470    1.709365
# 933     $74,541,707        102332848    1.705547
# 1345    $67,264,877         76665507    1.703678
# 3834    $16,033,556         17033556    1.703356
# 621     $69,117,629        136047317    1.700591
#
# [2774 rows x 11 columns]

# %%
fifty_percentile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2774 entries, 6013 to 621
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          2774 non-null   int64
#  1   runtime_minutes     2774 non-null   int64
#  2   genres              2774 non-null   object
#  3   production_company  2774 non-null   object
#  4   production_country  2774 non-null   object
#  5   release_date        2774 non-null   object
#  6   movie               2774 non-null   object
#  7   production_budget   2774 non-null   int64
#  8   domestic_gross      2774 non-null   object
#  9   worldwide_gross     2774 non-null   int64
#  10  profit              2774 non-null   float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 260.1+ KB

# %%
fifty_percentile['runtime_minutes'] = fifty_percentile['runtime_minutes'].astype(int)

# %%
fifty_percentile.describe()
# Out:
#         Unnamed: 0  runtime_minutes  production_budget  worldwide_gross  \
# count  2774.000000      2774.000000       2.774000e+03     2.774000e+03
# mean   2633.535328       110.663302       4.171565e+07     1.770353e+08
# std    1736.738173        20.719927       5.066191e+07     2.380441e+08
# min       0.000000        41.000000       1.000000e+05     4.294480e+05
# 25%    1065.250000        96.000000       8.500000e+06     3.817122e+07
# 50%    2552.500000       107.000000       2.200000e+07     9.481938e+07
# 75%    4093.750000       121.000000       5.500000e+07     2.149520e+08
# max    6086.000000       220.000000       4.000000e+08     2.845900e+09
#
#             profit
# count  2774.000000
# mean      7.775774
# std      22.380746
# min       1.700591
# 25%       2.552207
# 50%       3.788763
# 75%       6.506742
# max     498.750000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()

ax.scatter(x = fifty_percentile['runtime_minutes'], y = fifty_percentile['profit'])
ax.set_title('Movie Profits by Movie Runtime')
ax.set_xlabel('Runtime by Minutes')
ax.set_ylabel('Movie Profits');

# %%
import numpy as np

fig, ax = plt.subplots(figsize = (8,6))

x=fifty_percentile['runtime_minutes']
x_ticks = np.arange(40, 240, 10)
plt.xticks(x_ticks)

ax.hist(x, edgecolor="black", bins=20)
ax.set_title('Movie Runtime of Most Profitable Movies')
ax.set_xlabel('Runtime by Minutes')
ax.set_ylabel('Frequency');

# %%
import numpy as np

fig, ax = plt.subplots(figsize = (8,6))

ax.bar(x = fifty_percentile['runtime_minutes'], height = fifty_percentile['profit']);
