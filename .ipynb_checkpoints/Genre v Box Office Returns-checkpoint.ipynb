# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
tn_gross = pd.read_csv("./tngross.csv")
tn_production = pd.read_csv("./tnproduction.csv")

# %%
tn_gross
# Out:
#       Unnamed: 0  release_date                                        movie  \
# 0              0  Apr 23, 2019                            Avengers: Endgame
# 1              1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              2  Apr 22, 2015                      Avengers: Age of Ultron
# 3              3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              4  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6095        6095  Mar 17, 2015                                      Closure
# 6096        6096  Aug 29, 2015                            Lunch Time Heroes
# 6097        6097  Mar 25, 2015                                  Open Secret
# 6098        6098  Nov 10, 2015                            The Night Visitor
# 6099        6099   Jul 7, 2015                                 Tiger Orange
#
#      production_budget domestic_gross worldwide_gross
# 0         $400,000,000   $858,373,000  $2,797,800,564
# 1         $379,000,000   $241,071,802  $1,045,713,802
# 2         $365,000,000   $459,005,868  $1,395,316,979
# 3         $306,000,000   $936,662,225  $2,064,615,817
# 4         $300,000,000   $678,815,482  $2,044,540,523
# ...                ...            ...             ...
# 6095          $100,000             $0              $0
# 6096          $100,000             $0              $0
# 6097          $100,000             $0              $0
# 6098          $100,000             $0              $0
# 6099          $100,000             $0              $0
#
# [6100 rows x 6 columns]

# %%
tn_production
# Out:
#       Unnamed: 0 runtime_minutes       genres    production_company  \
# 0              0     181 minutes       Action        Marvel Studios
# 1              1     136 minutes    Adventure  Walt Disney Pictures
# 2              2     141 minutes       Action        Marvel Studios
# 3              3     136 minutes    Adventure  Lucasfilm, Bad Robot
# 4              4     156 minutes       Action        Marvel Studios
# ...          ...             ...          ...                   ...
# 6095        6095      90 minutes        Drama                  None
# 6096        6096      88 minutes    Adventure         Phebean Films
# 6097        6097            None  Documentary                  None
# 6098        6098            None       Horror                  None
# 6099        6099      81 minutes        Drama                  None
#
#      production_country
# 0         United States
# 1         United States
# 2         United States
# 3         United States
# 4         United States
# ...                 ...
# 6095      United States
# 6096            Nigeria
# 6097      United States
# 6098      United States
# 6099      United States
#
# [6100 rows x 5 columns]

# %%
df = tn_gross.merge(tn_production, on="Unnamed: 0")
df
# Out:
#       Unnamed: 0  release_date                                        movie  \
# 0              0  Apr 23, 2019                            Avengers: Endgame
# 1              1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              2  Apr 22, 2015                      Avengers: Age of Ultron
# 3              3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              4  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6095        6095  Mar 17, 2015                                      Closure
# 6096        6096  Aug 29, 2015                            Lunch Time Heroes
# 6097        6097  Mar 25, 2015                                  Open Secret
# 6098        6098  Nov 10, 2015                            The Night Visitor
# 6099        6099   Jul 7, 2015                                 Tiger Orange
#
#      production_budget domestic_gross worldwide_gross runtime_minutes  \
# 0         $400,000,000   $858,373,000  $2,797,800,564     181 minutes
# 1         $379,000,000   $241,071,802  $1,045,713,802     136 minutes
# 2         $365,000,000   $459,005,868  $1,395,316,979     141 minutes
# 3         $306,000,000   $936,662,225  $2,064,615,817     136 minutes
# 4         $300,000,000   $678,815,482  $2,044,540,523     156 minutes
# ...                ...            ...             ...             ...
# 6095          $100,000             $0              $0      90 minutes
# 6096          $100,000             $0              $0      88 minutes
# 6097          $100,000             $0              $0            None
# 6098          $100,000             $0              $0            None
# 6099          $100,000             $0              $0      81 minutes
#
#            genres    production_company production_country
# 0          Action        Marvel Studios      United States
# 1       Adventure  Walt Disney Pictures      United States
# 2          Action        Marvel Studios      United States
# 3       Adventure  Lucasfilm, Bad Robot      United States
# 4          Action        Marvel Studios      United States
# ...           ...                   ...                ...
# 6095        Drama                  None      United States
# 6096    Adventure         Phebean Films            Nigeria
# 6097  Documentary                  None      United States
# 6098       Horror                  None      United States
# 6099        Drama                  None      United States
#
# [6100 rows x 10 columns]

# %%
df["worldwide_gross"] = df["worldwide_gross"].str.replace('$', '')
df["domestic_gross"] = df["domestic_gross"].str.replace('$', '')
df["production_budget"] = df["production_budget"].str.replace('$', '')
df["worldwide_gross"] = df["worldwide_gross"].str.replace(',', '')
df["domestic_gross"] = df["domestic_gross"].str.replace(',', '')
df["production_budget"] = df["production_budget"].str.replace(',', '')
df["production_budget"]= df["production_budget"].astype(float)
df["domestic_gross"]= df["domestic_gross"].astype(float)
df["worldwide_gross"]= df["worldwide_gross"].astype(float)

# %%
df['s_movie_ratio'] = df['worldwide_gross'] / df['production_budget']
df
# Out:
#       Unnamed: 0  release_date                                        movie  \
# 0              0  Apr 23, 2019                            Avengers: Endgame
# 1              1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              2  Apr 22, 2015                      Avengers: Age of Ultron
# 3              3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              4  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6095        6095  Mar 17, 2015                                      Closure
# 6096        6096  Aug 29, 2015                            Lunch Time Heroes
# 6097        6097  Mar 25, 2015                                  Open Secret
# 6098        6098  Nov 10, 2015                            The Night Visitor
# 6099        6099   Jul 7, 2015                                 Tiger Orange
#
#       production_budget  domestic_gross  worldwide_gross runtime_minutes  \
# 0           400000000.0     858373000.0     2.797801e+09     181 minutes
# 1           379000000.0     241071802.0     1.045714e+09     136 minutes
# 2           365000000.0     459005868.0     1.395317e+09     141 minutes
# 3           306000000.0     936662225.0     2.064616e+09     136 minutes
# 4           300000000.0     678815482.0     2.044541e+09     156 minutes
# ...                 ...             ...              ...             ...
# 6095           100000.0             0.0     0.000000e+00      90 minutes
# 6096           100000.0             0.0     0.000000e+00      88 minutes
# 6097           100000.0             0.0     0.000000e+00            None
# 6098           100000.0             0.0     0.000000e+00            None
# 6099           100000.0             0.0     0.000000e+00      81 minutes
#
#            genres    production_company production_country  s_movie_ratio
# 0          Action        Marvel Studios      United States       6.994501
# 1       Adventure  Walt Disney Pictures      United States       2.759139
# 2          Action        Marvel Studios      United States       3.822786
# 3       Adventure  Lucasfilm, Bad Robot      United States       6.747111
# 4          Action        Marvel Studios      United States       6.815135
# ...           ...                   ...                ...            ...
# 6095        Drama                  None      United States       0.000000
# 6096    Adventure         Phebean Films            Nigeria       0.000000
# 6097  Documentary                  None      United States       0.000000
# 6098       Horror                  None      United States       0.000000
# 6099        Drama                  None      United States       0.000000
#
# [6100 rows x 11 columns]

# %%
s_movies_df = df.loc[df['s_movie_ratio'] >= 1.7]
s_movies_df
# Out:
#       Unnamed: 0  release_date                                        movie  \
# 0              0  Apr 23, 2019                            Avengers: Endgame
# 1              1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              2  Apr 22, 2015                      Avengers: Age of Ultron
# 3              3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              4  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6083        6083   Mar 1, 1987                            Hollywood Shuffle
# 6084        6084  Sep 17, 1920               Over the Hill to the Poorhouse
# 6085        6085   Oct 9, 1998                                   The Mighty
# 6086        6086   Jul 7, 2017                                A Ghost Story
# 6087        6087  May 10, 1980                                 Penitentiary
#
#       production_budget  domestic_gross  worldwide_gross runtime_minutes  \
# 0           400000000.0     858373000.0     2.797801e+09     181 minutes
# 1           379000000.0     241071802.0     1.045714e+09     136 minutes
# 2           365000000.0     459005868.0     1.395317e+09     141 minutes
# 3           306000000.0     936662225.0     2.064616e+09     136 minutes
# 4           300000000.0     678815482.0     2.044541e+09     156 minutes
# ...                 ...             ...              ...             ...
# 6083           100000.0       5228617.0     5.228617e+06            None
# 6084           100000.0       3000000.0     3.000000e+06     110 minutes
# 6085           100000.0       2652246.0     6.121582e+06            None
# 6086           100000.0       1594798.0     2.769782e+06      93 minutes
# 6087           100000.0        287000.0     2.870000e+05            None
#
#          genres                                 production_company  \
# 0        Action                                     Marvel Studios
# 1     Adventure                               Walt Disney Pictures
# 2        Action                                     Marvel Studios
# 3     Adventure                               Lucasfilm, Bad Robot
# 4        Action                                     Marvel Studios
# ...         ...                                                ...
# 6083       None                                               None
# 6084       None                                               None
# 6085      Drama                                               None
# 6086      Drama  Sailor Bear, Zero Trans Fat Productions, Ideam...
# 6087      Drama                                               None
#
#      production_country  s_movie_ratio
# 0         United States       6.994501
# 1         United States       2.759139
# 2         United States       3.822786
# 3         United States       6.747111
# 4         United States       6.815135
# ...                 ...            ...
# 6083      United States      52.286170
# 6084      United States      30.000000
# 6085      United States      61.215820
# 6086      United States      27.697820
# 6087      United States       2.870000
#
# [3048 rows x 11 columns]

# %%
genres_df = s_movies_df
genres_df = genres_df[genres_df.genres != "None"]
genres_df
# Out:
#       Unnamed: 0  release_date                                        movie  \
# 0              0  Apr 23, 2019                            Avengers: Endgame
# 1              1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2              2  Apr 22, 2015                      Avengers: Age of Ultron
# 3              3  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4              4  Apr 25, 2018                       Avengers: Infinity War
# ...          ...           ...                                          ...
# 6081        6081  Sep 29, 2006                            Facing the Giants
# 6082        6082          1977                                   Eraserhead
# 6085        6085   Oct 9, 1998                                   The Mighty
# 6086        6086   Jul 7, 2017                                A Ghost Story
# 6087        6087  May 10, 1980                                 Penitentiary
#
#       production_budget  domestic_gross  worldwide_gross runtime_minutes  \
# 0           400000000.0     858373000.0     2.797801e+09     181 minutes
# 1           379000000.0     241071802.0     1.045714e+09     136 minutes
# 2           365000000.0     459005868.0     1.395317e+09     141 minutes
# 3           306000000.0     936662225.0     2.064616e+09     136 minutes
# 4           300000000.0     678815482.0     2.044541e+09     156 minutes
# ...                 ...             ...              ...             ...
# 6081           100000.0      10178331.0     1.024316e+07            None
# 6082           100000.0       7000000.0     7.097971e+06      89 minutes
# 6085           100000.0       2652246.0     6.121582e+06            None
# 6086           100000.0       1594798.0     2.769782e+06      93 minutes
# 6087           100000.0        287000.0     2.870000e+05            None
#
#          genres                                 production_company  \
# 0        Action                                     Marvel Studios
# 1     Adventure                               Walt Disney Pictures
# 2        Action                                     Marvel Studios
# 3     Adventure                               Lucasfilm, Bad Robot
# 4        Action                                     Marvel Studios
# ...         ...                                                ...
# 6081      Drama                                               None
# 6082     Horror                                               None
# 6085      Drama                                               None
# 6086      Drama  Sailor Bear, Zero Trans Fat Productions, Ideam...
# 6087      Drama                                               None
#
#      production_country  s_movie_ratio
# 0         United States       6.994501
# 1         United States       2.759139
# 2         United States       3.822786
# 3         United States       6.747111
# 4         United States       6.815135
# ...                 ...            ...
# 6081      United States     102.431590
# 6082      United States      70.979710
# 6085      United States      61.215820
# 6086      United States      27.697820
# 6087      United States       2.870000
#
# [3000 rows x 11 columns]

# %%
plt.figure(figsize=(10, 10))
plt.scatter(
    x=genres_df["genres"], 
    y=genres_df["worldwide_gross"], 
)
plt.xticks(rotation=45)
plt.ticklabel_format(axis="y", style="plain")
;
# Out:
# ''

# %%
plt.figure(figsize=(10, 10))
plt.bar(
    x=genres_df["genres"], 
    height=genres_df["worldwide_gross"])
plt.xticks(rotation=45)
plt.ticklabel_format(axis="y", style="plain")
;
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-3cabeebec6e8> in <module>
#       1 plt.figure(figsize=(10, 10))
#       2 plt.bar(
# ----> 3     x=genres_df["genres"].sort,
#       4     height=genres_df["worldwide_gross"])
#       5 plt.xticks(rotation=45)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'sort'

# %%
fig, ax =plt.subplots()

ax.plot(genres_df["genres"],genres_df["worldwide_gross"])
plt.xticks(rotation=45)
plt.ticklabel_format(axis="y", style="plain")
;
# Out:
# ''

# %%
# plot wordcloud
